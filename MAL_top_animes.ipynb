# %% [markdown]
# # Web_Scraping project 01

# %% [markdown]
# Web scrape from multiple pages from the same topic. The number you give to the 'main()' function will be multipy by 50 in order to get the web page.

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from selenium import webdriver
import chromedriver_binary
import requests
from csv import writer

# %%
data = []

def main(number):
    driver = webdriver.Chrome()
    url = 'https://myanimelist.net/topanime.php?limit={}'

    
    if number <= 1:
        driver.get(url.format(0))
        soup = BeautifulSoup(driver.page_source, 'html.parser')
        results = soup.find_all('tr', class_= 'ranking-list')

        for result in results:
            Anime = result.find('h3', class_='hoverinfo_trigger fl-l fs14 fw-b anime_ranking_h3').get_text(strip=True)
            Date = result.find('div', class_='information di-ib mt4')contents[2].get_text(strip=True)
            No_eps = result.find('div', class_='information di-ib mt4')contents[0].get_text(strip=True)
            Ranking = result.find('td', class_='rank ac').get_text(strip=True)
            Score = result.find('div', class_='js-top-ranking-score-col di-ib al').get_text(strip=True)
            data.append({
                'Anime':Anime,
                'Date':Date,
                'No_eps':No_eps,
                'Ranking':Ranking,
                'Score':Score
            })
    elif number >= 2:
        for limit in range(0,(int(number)*50), 50):
            driver.get(url.format(limit))

            soup = BeautifulSoup(driver.page_source, 'html.parser')
            results = soup.find_all('tr', class_= 'ranking-list')

            for result in results:
                Anime = result.find('h3', class_='hoverinfo_trigger fl-l fs14 fw-b anime_ranking_h3').get_text(strip=True)
                Date = result.find('div', class_='information di-ib mt4')contents[2].get_text(strip=True)
                No_eps = result.find('div', class_='information di-ib mt4')contents[0].get_text(strip=True)
                Ranking = result.find('td', class_='rank ac').get_text(strip=True)
                Score = result.find('div', class_='js-top-ranking-score-col di-ib al').get_text(strip=True)
                data.append({
                    'Anime':Anime,
                    'Date':Date,
                    'No_eps':No_eps,
                    'Ranking':Ranking,
                    'Score':Score
                })
#                print(info) #info y print info es para verificar que funciona el scrap, with open no se incluye en el chequep
            
#             with open('MAL_topanime.csv', 'w', newline='', encoding='utf-8') as f:
#                 writer = csv.writer(f)
#                 header = ['Anime','Date', 'No_eps', 'Ranking', 'Score']
#                 writer.writerow(header)
#                 writer.writerow(info)

# %%
main(2)

# %%
dfs = pd.DataFrame(data).drop_duplicates()
dfs
# Out:
#                                              Anime  \
# 0                 Fullmetal Alchemist: Brotherhood
# 1                        Bleach: Sennen Kessen-hen
# 2       Kaguya-sama wa Kokurasetai: Ultra Romantic
# 3                                         Gintama°
# 4                                      Steins;Gate
# ..                                             ...
# 95                         Zoku Natsume Yuujinchou
# 96  Neon Genesis Evangelion: The End of Evangelion
# 97                                  Road of Naruto
# 98             Shoujo☆Kageki Revue Starlight Movie
# 99                            Mushishi: Hihamukage
#
#                                                  Date  \
# 0     TV (64 eps)Apr 2009 - Jul 20103,004,198 members
# 1                 TV (? eps)Oct 2022 -248,110 members
# 2       TV (13 eps)Apr 2022 - Jun 2022673,200 members
# 3       TV (51 eps)Apr 2015 - Mar 2016559,125 members
# 4     TV (24 eps)Apr 2011 - Sep 20112,313,966 members
# ..                                                ...
# 95      TV (13 eps)Jan 2009 - Mar 2009231,452 members
# 96    Movie (1 eps)Jul 1997 - Jul 1997825,371 members
# 97        ONA (1 eps)Oct 2022 - Oct 20228,948 members
# 98     Movie (1 eps)Jun 2021 - Jun 202112,590 members
# 99  Special (1 eps)Jan 2014 - Jan 2014128,270 members
#
#                                                No_eps Ranking Score
# 0     TV (64 eps)Apr 2009 - Jul 20103,004,198 members       1  9.12
# 1                 TV (? eps)Oct 2022 -248,110 members       2  9.11
# 2       TV (13 eps)Apr 2022 - Jun 2022673,200 members       3  9.10
# 3       TV (51 eps)Apr 2015 - Mar 2016559,125 members       4  9.08
# 4     TV (24 eps)Apr 2011 - Sep 20112,313,966 members       5  9.08
# ..                                                ...     ...   ...
# 95      TV (13 eps)Jan 2009 - Mar 2009231,452 members      96  8.55
# 96    Movie (1 eps)Jul 1997 - Jul 1997825,371 members      97  8.55
# 97        ONA (1 eps)Oct 2022 - Oct 20228,948 members      98  8.55
# 98     Movie (1 eps)Jun 2021 - Jun 202112,590 members      99  8.55
# 99  Special (1 eps)Jan 2014 - Jan 2014128,270 members     100  8.54
#
# [100 rows x 5 columns]

# %%
#Saving dataframe
#dfs.to_csv("***.csv")
